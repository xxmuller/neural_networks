# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import densenet
from tensorflow.keras.applications.resnet import ResNet101
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Activation, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.keras import datasets, layers, models, optimizers, activations, regularizers

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# Load dataset and pre-process data
(X_train, y_train), (X_test, y_test) = cifar100.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Split the data into test and validation data
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, test_size=0.7)

# %%
# Dataset class labels
labels =  ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 
           'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 
           'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'computer_keyboard', 
           'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 
           'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 
           'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 
           'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 
           'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 
           'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']

# %%
# Visualize several images and their classes from the training set
plt.figure(figsize=(20, 3))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap="gray")
    plt.xlabel(labels[y_train[i].astype(int)[0]])
    
plt.show()

# %%
# Convert labels to one hot encoding matrix
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)
y_valid = to_categorical(y_valid, 100)

# %%
# Function for model building
def build_model(input_shape, n_classes):
    """
    Build model from DenseNet. Retrain last 5 layers and adds 2 Dense layers.
    :param input_shape: shape of single image
    :param n_classes: number of classes for prediction
    :return model: compiled model
    """
#    base_model = densenet.DenseNet121(input_shape=input_shape,
#                                      weights="imagenet",
#                                      include_top=False,
#                                      pooling='avg')
    base_model = ResNet101(include_top=False,weights='imagenet',input_shape=(32,32,3),classes=100,pooling='avg')

    for layer in base_model.layers[:-5]:
        layer.trainable = False

    for layer in base_model.layers[-5:]:
        layer.trainable = True

    x = base_model.output

    x = Dense(128)(x)
    x = Dropout(0.2)(x)
    x = Activation('relu')(x)
    predictions = Dense(n_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
def resnet_layer(inputs, num_filters=16, kernel_size=6, strides=1, activation='relu',
                 batch_normalization=True, conv_first=True, regularization=False):
    
    conv = layers.Conv2D(num_filters, kernel_size=kernel_size, strides=strides, padding='same',
                  kernel_initializer='he_normal')

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = layers.BatchNormalization()(x)
        if activation is not None:
            x = layers.Activation(activation)(x)
    else:
        if batch_normalization:
            x = layers.BatchNormalization()(x)
        if activation is not None:
            x = layers.Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet(input_shape, depth, num_classes=100):
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = layers.Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:
                strides = 2
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None,
                             regularization=True)
            if stack > 0 and res_block == 0:
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)

            x = layers.add([x, y])
            x = layers.Activation('relu')(x)
        num_filters *= 2
        
    x = layers.AveragePooling2D(pool_size=8)(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.2)(x)
    y = layers.Flatten()(x)
    
    outputs = layers.Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Build model and get summary
#model = build_model(input_shape=(32, 32, 3), n_classes=len(labels))
model = resnet_model = resnet(input_shape=(32, 32, 3), depth=50)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   1744        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   9232        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   9232        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['activation[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   9232        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   9232        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['activation_2[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   9232        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   9232        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['activation_4[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 16)   9232        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   9232        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 32, 32, 16)   0           ['activation_6[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['add_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   9232        ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 16)   0           ['activation_8[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['add_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 16)   0           ['activation_10[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 16)   0           ['add_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 16)  64          ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 16)   0           ['activation_12[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['add_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 16)   0           ['activation_14[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['add_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 32)   18464       ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 32)  128         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 32)   544         ['activation_16[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 32)  128         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 16, 16, 32)   0           ['conv2d_19[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_18 (Activation)     (None, 16, 16, 32)   0           ['add_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 32)  128         ['conv2d_21[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 16, 16, 32)   0           ['activation_18[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_20 (Activation)     (None, 16, 16, 32)   0           ['add_9[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 16, 16, 32)   0           ['activation_20[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_22 (Activation)     (None, 16, 16, 32)   0           ['add_10[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 32)  128         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 32)  128         ['conv2d_25[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 16, 32)   0           ['activation_22[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 32)   0           ['add_11[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 32)  128         ['conv2d_27[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 32)   0           ['activation_24[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 32)   0           ['add_12[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 32)   0           ['activation_26[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_28 (Activation)     (None, 16, 16, 32)   0           ['add_13[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 32)  128         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 32)  128         ['conv2d_31[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 16, 16, 32)   0           ['activation_28[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 32)   0           ['add_14[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 32)   36896       ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 16, 16, 32)   0           ['activation_30[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_32 (Activation)     (None, 16, 16, 32)   0           ['add_15[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 64)     73792       ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 64)    256         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 64)     2112        ['activation_32[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 64)    256         ['conv2d_35[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 8, 8, 64)     0           ['conv2d_36[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_34 (Activation)     (None, 8, 8, 64)     0           ['add_16[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 64)    256         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 64)    256         ['conv2d_38[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 8, 8, 64)     0           ['activation_34[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_36 (Activation)     (None, 8, 8, 64)     0           ['add_17[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 64)    256         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 64)    256         ['conv2d_40[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 8, 8, 64)     0           ['activation_36[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['add_18[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 64)    256         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 64)    256         ['conv2d_42[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 8, 8, 64)     0           ['activation_38[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['add_19[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 64)    256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 64)    256         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 8, 8, 64)     0           ['activation_40[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 64)     0           ['add_20[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 64)    256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 64)    256         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 8, 8, 64)     0           ['activation_42[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  activation_44 (Activation)     (None, 8, 8, 64)     0           ['add_21[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 64)    256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 64)    256         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 8, 8, 64)     0           ['activation_44[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_46 (Activation)     (None, 8, 8, 64)     0           ['add_22[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 8, 8, 64)    256         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_47[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 8, 8, 64)     147520      ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 8, 8, 64)    256         ['conv2d_50[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 8, 8, 64)     0           ['activation_46[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  activation_48 (Activation)     (None, 8, 8, 64)     0           ['add_23[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 64)    0           ['activation_48[0][0]']
#  ing2D)
#
#  activation_49 (Activation)     (None, 1, 1, 64)     0           ['average_pooling2d[0][0]']
#
#  dropout (Dropout)              (None, 1, 1, 64)     0           ['activation_49[0][0]']
#
#  flatten (Flatten)              (None, 64)           0           ['dropout[0][0]']
#
#  dense (Dense)                  (None, 100)          6500        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 3,024,340
# Trainable params: 3,020,724
# Non-trainable params: 3,616
# __________________________________________________________________________________________________

# %%
# Generate augmented images
datagen = ImageDataGenerator(
    height_shift_range=0.2,
    width_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=40,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
)

datagen.fit(X_train)

# %%
# Set checkpointer and train model
model_checkpointer = ModelCheckpoint('cifar100_best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
history = model.fit(datagen.flow(X_train, y_train, batch_size=128, shuffle=True), validation_data=(X_valid, y_valid), epochs=100, verbose=1,  
               callbacks=[EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=15), model_checkpointer])
# Out:
# Epoch 1/150
# 180/391 [============>.................] - ETA: 1:25 - loss: 4.6149 - accuracy: 0.0217
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       1 # Set checkpointer and train model
#       2 model_checkpointer = ModelCheckpoint('cifar100_best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# ----> 3 history = model.fit(datagen.flow(X_train, y_train, batch_size=128, shuffle=True), validation_data=(X_valid, y_valid), epochs=150, verbose=1,
#       4                callbacks=[EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=15), model_checkpointer])
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\engine\training.py:1389, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387 logs = tmp_logs  # No error, now safe to assign to logs.
#    1388 end_step = step + data_handler.step_increment
# -> 1389 callbacks.on_train_batch_end(end_step, logs)
#    1390 if self.stop_training:
#    1391   break
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\callbacks.py:356, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
# --> 356   hook(batch, logs)
#     358 if self._check_timing:
#     359   if hook_name not in self._hook_times:
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\callbacks.py:1034, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1033 def on_train_batch_end(self, batch, logs=None):
# -> 1034   self._batch_update_progbar(batch, logs)
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\callbacks.py:1106, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1102   self.seen += add_seen
#    1104 if self.verbose == 1:
#    1105   # Only block async when verbose = 1.
# -> 1106   logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\utils\tf_utils.py:563, in sync_to_numpy_or_python_type(tensors)
#     560     return t
#     561   return t.item() if np.ndim(t) == 0 else t
# --> 563 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\tensorflow\python\util\nest.py:914, in map_structure(func, *structure, **kwargs)
#     910 flat_structure = (flatten(s, expand_composites) for s in structure)
#     911 entries = zip(*flat_structure)
#     913 return pack_sequence_as(
# --> 914     structure[0], [func(*x) for x in entries],
#     915     expand_composites=expand_composites)
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\tensorflow\python\util\nest.py:914, in <listcomp>(.0)
#     910 flat_structure = (flatten(s, expand_composites) for s in structure)
#     911 entries = zip(*flat_structure)
#     913 return pack_sequence_as(
# --> 914     structure[0], [func(*x) for x in entries],
#     915     expand_composites=expand_composites)
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\keras\utils\tf_utils.py:557, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     554 def _to_single_numpy_or_python_type(t):
#     555   # Don't turn ragged or sparse tensors to NumPy.
#     556   if isinstance(t, tf.Tensor):
# --> 557     t = t.numpy()
#     558   # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559   if not isinstance(t, (np.ndarray, np.generic)):
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\tensorflow\python\framework\ops.py:1223, in _EagerTensorBase.numpy(self)
#    1200 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1201
#    1202 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1220     NumPy dtype.
#    1221 """
#    1222 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File C:\FIIT\NN\project_2\venv\lib\site-packages\tensorflow\python\framework\ops.py:1189, in _EagerTensorBase._numpy(self)
#    1187 def _numpy(self):
#    1188   try:
# -> 1189     return self._numpy_internal()
#    1190   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:
