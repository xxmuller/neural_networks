# %% [markdown]
# # ResNet50
#
# V tomto notebooku je uvedený náš model vytvorený pomocou konvolučnej neurónovej siete ResNet50 z TensorFlow knižnice. ResNet50 je tzv. reziduálna konvolučná sieť, ktorá je hlboká 50 vrstiev. Reziduálna konvolučná sieť je taká sieť, ktorá na seba ukladá reziduálne bloky a tak vytvára sieť.
#
# Pomocou nami vytvoreného modelu sme sa snažili klasifikovať dataset obrázkov CIFAR-100, ktorý obsahuje 100 tried obrázkov. Následne sme tento model vyskúšali aj na menšom datasete CIFAR-10.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
import tensorflow.keras as keras
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Input, UpSampling2D, Flatten, BatchNormalization, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras import optimizers
from keras.datasets import cifar100
import tensorflow as tf
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import time
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix , classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split

# %%
if not tf.test.gpu_device_name():
    print("No GPU found")
else:
    print("GPU name: {}".format(tf.test.gpu_device_name()))
# Out:
# GPU name: /device:GPU:0

# %% [markdown]
# ### Načítanie datasetu

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# %%
labels =  ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 
           'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 
           'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'computer_keyboard', 
           'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 
           'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 
           'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 
           'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 
           'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 
           'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']

# %% [markdown]
# ### Ukážka dát

# %%
plt.figure(figsize=(10,10))
for i in range(36):
    plt.subplot(6,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])

    plt.xlabel(labels[y_train[i][0]])
plt.show()

# %% [markdown]
# ### Predspracovanie dát
#
# Na predspracovanie dát sme využili funkciu z knižnice TensorFlow, aby sa naše dáta čo najlepšie hodili do požadovanej siete ResNet50.

# %%
# pre-process the data
x_train = preprocess_input(x_train)
x_test = preprocess_input(x_test)

# %% [markdown]
# ### Nastavenie augmentácie nášho trénovacieho datasetu
#
# Náš model sme najskôr trénovali bez augmentácie, avšak nemali sme dostatočne dobré výsledky. Z výsledkov nášho starého modelu sme tiež videli, že dochádza k tzv. overfittingu. Preto sme sa rozhodli pridať augmentáciu dát, ktorá dokáže riešiť problém overfittingu tým, že umelo vygeneruje nové obrázky, ktoré sú nejakým spôsobom upravené. V našom prípade sme zvolili horizontálne a vertikálne prevrátenie, rotáciu a posuny šírky a výšky atď.

# %%
# Generate augmented images
datagen = ImageDataGenerator(
    height_shift_range=0.2,
    width_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=40,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
)
datagen.fit(x_train)

# %% [markdown]
# ### Rozdelenie testovacích dát na testovacie a validačné
#
# Našu testovaciu množinu dát sme rozdelili na testovaciu a validačnú v pomere 70:30

# %%
x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.7)

# %%
num_classes = 100

y_train = np_utils.to_categorical(y_train, num_classes)
y_valid = np_utils.to_categorical(y_valid, num_classes)
#y_test = np_utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ## Vytváranie modelu
#
# V tejto časti vytvárame náš konkrétny model. Na vytvorenie modelu používame sieť z TensorFlow knižnice -> teda ResNet50. K tejto sieti následne pridávame ďalšie vrstvy. Skúšali sme viaceré varianty, ale nižšie vytvorený model mal zo všetkých najväčšiu úspešnosť. Ako prvé pridávame vrtsvu GlobalAveragePooling2D, následne pridávame aktivačnú Dense vrstvu s aktivačnou funkciou ReLu, pridávame BatchNormalization a nakoniec máme poslednú Dense vrstvu s aktivačnou funkciou SoftMax.
#
# Keďže sme mali problém s overfittingom nášho modelu, tak sme skúšali pridávať aj Dropout vrstvy, avšak tie nemali nejaký výrazný vplyv na výkon modelu a zlepšenie overfittingu. Tento problém sme vyriešili pridaním augmentácie obrázkov opísanej vyššie.

# %%
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

for layer in resnet_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

model = Sequential()
model.add(resnet_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 1, 1, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dense_4 (Dense)             (None, 100)               12900
#
# =================================================================
# Total params: 24,421,476
# Trainable params: 886,628
# Non-trainable params: 23,534,848
# _________________________________________________________________

# %% [markdown]
# ## Trénovanie modelu
#
# Náš model sa trénoval na 100 epochách. Skúšali sme viacero možností batch size, ale ako najlepšie nám vyšiel batch size s  veľkosťou 64 obrázkov. Pri trénovaní bolo použité EarlyStopping, ktoré bolo nastavené tak, že keď sa 10 epôch po sebe nezlepšila hodnota val_accuracy, tak sa trénovanie ukončilo.
#
# Najlepší model si ukladáme pomocou ModelCheckpointu.

# %%
epochs = 100
batch_size = 64

# Set checkpointer and train model
model_checkpointer = ModelCheckpoint('cifar100_best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

t=time.time()
history = model.fit(datagen.flow(x_train, y_train,
                                  batch_size=batch_size),
                                  steps_per_epoch=x_train.shape[0] // batch_size,
                                  epochs=epochs,
                                  validation_data=(x_valid, y_valid),
                                 callbacks=[EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10), model_checkpointer])
print('Training time: %s' % (t - time.time()))
# Out:
# Epoch 1/100
# 781/781 [==============================] - ETA: 0s - loss: 3.8384 - accuracy: 0.1255
# Epoch 1: val_accuracy improved from -inf to 0.20657, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 78s 85ms/step - loss: 3.8384 - accuracy: 0.1255 - val_loss: 3.3063 - val_accuracy: 0.2066
# Epoch 2/100
# 781/781 [==============================] - ETA: 0s - loss: 3.2476 - accuracy: 0.2123
# Epoch 2: val_accuracy improved from 0.20657 to 0.26457, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 63s 81ms/step - loss: 3.2476 - accuracy: 0.2123 - val_loss: 2.9566 - val_accuracy: 0.2646
# Epoch 3/100
# 781/781 [==============================] - ETA: 0s - loss: 3.0297 - accuracy: 0.2443
# Epoch 3: val_accuracy improved from 0.26457 to 0.29329, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 63s 80ms/step - loss: 3.0297 - accuracy: 0.2443 - val_loss: 2.7485 - val_accuracy: 0.2933
# Epoch 4/100
# 781/781 [==============================] - ETA: 0s - loss: 2.9074 - accuracy: 0.2711
# Epoch 4: val_accuracy improved from 0.29329 to 0.31329, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.9074 - accuracy: 0.2711 - val_loss: 2.6639 - val_accuracy: 0.3133
# Epoch 5/100
# 781/781 [==============================] - ETA: 0s - loss: 2.8090 - accuracy: 0.2870
# Epoch 5: val_accuracy improved from 0.31329 to 0.33286, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.8090 - accuracy: 0.2870 - val_loss: 2.5179 - val_accuracy: 0.3329
# Epoch 6/100
# 781/781 [==============================] - ETA: 0s - loss: 2.7252 - accuracy: 0.3064
# Epoch 6: val_accuracy improved from 0.33286 to 0.34729, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.7252 - accuracy: 0.3064 - val_loss: 2.4832 - val_accuracy: 0.3473
# Epoch 7/100
# 781/781 [==============================] - ETA: 0s - loss: 2.6660 - accuracy: 0.3161
# Epoch 7: val_accuracy improved from 0.34729 to 0.35000, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.6660 - accuracy: 0.3161 - val_loss: 2.4703 - val_accuracy: 0.3500
# Epoch 8/100
# 781/781 [==============================] - ETA: 0s - loss: 2.6137 - accuracy: 0.3298
# Epoch 8: val_accuracy improved from 0.35000 to 0.37043, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.6137 - accuracy: 0.3298 - val_loss: 2.3946 - val_accuracy: 0.3704
# Epoch 9/100
# 781/781 [==============================] - ETA: 0s - loss: 2.5726 - accuracy: 0.3348
# Epoch 9: val_accuracy improved from 0.37043 to 0.37829, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.5726 - accuracy: 0.3348 - val_loss: 2.3483 - val_accuracy: 0.3783
# Epoch 10/100
# 781/781 [==============================] - ETA: 0s - loss: 2.5203 - accuracy: 0.3478
# Epoch 10: val_accuracy improved from 0.37829 to 0.38729, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 79ms/step - loss: 2.5203 - accuracy: 0.3478 - val_loss: 2.3004 - val_accuracy: 0.3873
# Epoch 11/100
# 781/781 [==============================] - ETA: 0s - loss: 2.4863 - accuracy: 0.3550
# Epoch 11: val_accuracy improved from 0.38729 to 0.39514, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.4863 - accuracy: 0.3550 - val_loss: 2.2859 - val_accuracy: 0.3951
# Epoch 12/100
# 781/781 [==============================] - ETA: 0s - loss: 2.4589 - accuracy: 0.3602
# Epoch 12: val_accuracy did not improve from 0.39514
# 781/781 [==============================] - 62s 79ms/step - loss: 2.4589 - accuracy: 0.3602 - val_loss: 2.2961 - val_accuracy: 0.3896
# Epoch 13/100
# 781/781 [==============================] - ETA: 0s - loss: 2.4360 - accuracy: 0.3646
# Epoch 13: val_accuracy improved from 0.39514 to 0.40071, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 79ms/step - loss: 2.4360 - accuracy: 0.3646 - val_loss: 2.2136 - val_accuracy: 0.4007
# Epoch 14/100
# 781/781 [==============================] - ETA: 0s - loss: 2.4038 - accuracy: 0.3702
# Epoch 14: val_accuracy improved from 0.40071 to 0.41443, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.4038 - accuracy: 0.3702 - val_loss: 2.1588 - val_accuracy: 0.4144
# Epoch 15/100
# 781/781 [==============================] - ETA: 0s - loss: 2.3822 - accuracy: 0.3763
# Epoch 15: val_accuracy did not improve from 0.41443
# 781/781 [==============================] - 62s 79ms/step - loss: 2.3822 - accuracy: 0.3763 - val_loss: 2.1938 - val_accuracy: 0.4130
# Epoch 16/100
# 781/781 [==============================] - ETA: 0s - loss: 2.3665 - accuracy: 0.3814
# Epoch 16: val_accuracy did not improve from 0.41443
# 781/781 [==============================] - 61s 78ms/step - loss: 2.3665 - accuracy: 0.3814 - val_loss: 2.2209 - val_accuracy: 0.4067
# Epoch 17/100
# 781/781 [==============================] - ETA: 0s - loss: 2.3339 - accuracy: 0.3849
# Epoch 17: val_accuracy improved from 0.41443 to 0.42171, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 79ms/step - loss: 2.3339 - accuracy: 0.3849 - val_loss: 2.1585 - val_accuracy: 0.4217
# Epoch 18/100
# 781/781 [==============================] - ETA: 0s - loss: 2.3172 - accuracy: 0.3876
# Epoch 18: val_accuracy did not improve from 0.42171
# 781/781 [==============================] - 61s 79ms/step - loss: 2.3172 - accuracy: 0.3876 - val_loss: 2.1676 - val_accuracy: 0.4207
# Epoch 19/100
# 781/781 [==============================] - ETA: 0s - loss: 2.2941 - accuracy: 0.3913
# Epoch 19: val_accuracy improved from 0.42171 to 0.42486, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 79ms/step - loss: 2.2941 - accuracy: 0.3913 - val_loss: 2.1074 - val_accuracy: 0.4249
# Epoch 20/100
# 781/781 [==============================] - ETA: 0s - loss: 2.2795 - accuracy: 0.3980
# Epoch 20: val_accuracy did not improve from 0.42486
# 781/781 [==============================] - 61s 79ms/step - loss: 2.2795 - accuracy: 0.3980 - val_loss: 2.1603 - val_accuracy: 0.4230
# Epoch 21/100
# 781/781 [==============================] - ETA: 0s - loss: 2.2678 - accuracy: 0.4011
# Epoch 21: val_accuracy did not improve from 0.42486
# 781/781 [==============================] - 61s 79ms/step - loss: 2.2678 - accuracy: 0.4011 - val_loss: 2.1979 - val_accuracy: 0.4164
# Epoch 22/100
# 781/781 [==============================] - ETA: 0s - loss: 2.2634 - accuracy: 0.4018
# Epoch 22: val_accuracy improved from 0.42486 to 0.43286, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 79ms/step - loss: 2.2634 - accuracy: 0.4018 - val_loss: 2.0982 - val_accuracy: 0.4329
# Epoch 23/100
# 781/781 [==============================] - ETA: 0s - loss: 2.2347 - accuracy: 0.4075
# Epoch 23: val_accuracy did not improve from 0.43286
# 781/781 [==============================] - 61s 79ms/step - loss: 2.2347 - accuracy: 0.4075 - val_loss: 2.1370 - val_accuracy: 0.4313
# Epoch 24/100
# 781/781 [==============================] - ETA: 0s - loss: 2.2238 - accuracy: 0.4121
# Epoch 24: val_accuracy improved from 0.43286 to 0.43514, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 79ms/step - loss: 2.2238 - accuracy: 0.4121 - val_loss: 2.0983 - val_accuracy: 0.4351
# Epoch 25/100
# 781/781 [==============================] - ETA: 0s - loss: 2.2072 - accuracy: 0.4150
# Epoch 25: val_accuracy did not improve from 0.43514
# 781/781 [==============================] - 61s 79ms/step - loss: 2.2072 - accuracy: 0.4150 - val_loss: 2.1352 - val_accuracy: 0.4336
# Epoch 26/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1960 - accuracy: 0.4177
# Epoch 26: val_accuracy improved from 0.43514 to 0.43657, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 79ms/step - loss: 2.1960 - accuracy: 0.4177 - val_loss: 2.1228 - val_accuracy: 0.4366
# Epoch 27/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1822 - accuracy: 0.4190
# Epoch 27: val_accuracy improved from 0.43657 to 0.43971, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 80ms/step - loss: 2.1822 - accuracy: 0.4190 - val_loss: 2.1200 - val_accuracy: 0.4397
# Epoch 28/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1756 - accuracy: 0.4198
# Epoch 28: val_accuracy improved from 0.43971 to 0.44957, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 62s 79ms/step - loss: 2.1756 - accuracy: 0.4198 - val_loss: 2.0492 - val_accuracy: 0.4496
# Epoch 29/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1626 - accuracy: 0.4210
# Epoch 29: val_accuracy did not improve from 0.44957
# 781/781 [==============================] - 61s 79ms/step - loss: 2.1626 - accuracy: 0.4210 - val_loss: 2.0947 - val_accuracy: 0.4370
# Epoch 30/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1485 - accuracy: 0.4268
# Epoch 30: val_accuracy did not improve from 0.44957
# 781/781 [==============================] - 61s 79ms/step - loss: 2.1485 - accuracy: 0.4268 - val_loss: 2.0847 - val_accuracy: 0.4414
# Epoch 31/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1401 - accuracy: 0.4271
# Epoch 31: val_accuracy did not improve from 0.44957
# 781/781 [==============================] - 61s 79ms/step - loss: 2.1401 - accuracy: 0.4271 - val_loss: 2.0931 - val_accuracy: 0.4444
# Epoch 32/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1233 - accuracy: 0.4341
# Epoch 32: val_accuracy did not improve from 0.44957
# 781/781 [==============================] - 61s 78ms/step - loss: 2.1233 - accuracy: 0.4341 - val_loss: 2.0647 - val_accuracy: 0.4486
# Epoch 33/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1154 - accuracy: 0.4339
# Epoch 33: val_accuracy did not improve from 0.44957
# 781/781 [==============================] - 61s 78ms/step - loss: 2.1154 - accuracy: 0.4339 - val_loss: 2.0801 - val_accuracy: 0.4471
# Epoch 34/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1147 - accuracy: 0.4341
# Epoch 34: val_accuracy improved from 0.44957 to 0.45314, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 61s 78ms/step - loss: 2.1147 - accuracy: 0.4341 - val_loss: 2.0498 - val_accuracy: 0.4531
# Epoch 35/100
# 781/781 [==============================] - ETA: 0s - loss: 2.1008 - accuracy: 0.4347
# Epoch 35: val_accuracy improved from 0.45314 to 0.45586, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 61s 78ms/step - loss: 2.1008 - accuracy: 0.4347 - val_loss: 2.0418 - val_accuracy: 0.4559
# Epoch 36/100
# 781/781 [==============================] - ETA: 0s - loss: 2.0881 - accuracy: 0.4397
# Epoch 36: val_accuracy did not improve from 0.45586
# 781/781 [==============================] - 61s 78ms/step - loss: 2.0881 - accuracy: 0.4397 - val_loss: 2.0511 - val_accuracy: 0.4541
# Epoch 37/100
# 781/781 [==============================] - ETA: 0s - loss: 2.0768 - accuracy: 0.4433
# Epoch 37: val_accuracy improved from 0.45586 to 0.45943, saving model to cifar100_best_model.h5
# 781/781 [==============================] - 61s 78ms/step - loss: 2.0768 - accuracy: 0.4433 - val_loss: 2.0251 - val_accuracy: 0.4594
# Epoch 38/100
# 781/781 [==============================] - ETA: 0s - loss: 2.0691 - accuracy: 0.4429
# Epoch 38: val_accuracy did not improve from 0.45943
# 781/781 [==============================] - 61s 78ms/step - loss: 2.0691 - accuracy: 0.4429 - val_loss: 2.0529 - val_accuracy: 0.4551
# Epoch 39/100
# 781/781 [==============================] - ETA: 0s - loss: 2.0643 - accuracy: 0.4474
# Epoch 39: val_accuracy did not improve from 0.45943
# 781/781 [==============================] - 61s 78ms/step - loss: 2.0643 - accuracy: 0.4474 - val_loss: 2.0317 - val_accuracy: 0.4590
# Epoch 40/100
# 781/781 [==============================] - ETA: 0s - loss: 2.0644 - accuracy: 0.4442
# Epoch 40: val_accuracy did not improve from 0.45943
# 781/781 [==============================] - 61s 78ms/step - loss: 2.0644 - accuracy: 0.4442 - val_loss: 2.0253 - val_accuracy: 0.4579
# Epoch 41/100
# 781/781 [==============================] - ETA: 0s - loss: 2.
100
# 781/781 [==============================] - ETA: 0s - loss: 1.9483 - accuracy: 0.4719
# Epoch 56: val_accuracy did not improve from 0.47086
# 781/781 [==============================] - 67s 86ms/step - loss: 1.9483 - accuracy: 0.4719 - val_loss: 2.0290 - val_accuracy: 0.4630
# Epoch 57/100
# 781/781 [==============================] - ETA: 0s - loss: 1.9352 - accuracy: 0.4726
# Epoch 57: val_accuracy did not improve from 0.47086
# 781/781 [==============================] - 63s 81ms/step - loss: 1.9352 - accuracy: 0.4726 - val_loss: 2.0059 - val_accuracy: 0.4646
# Epoch 57: early stopping
# Training time: -3592.083173751831

# %% [markdown]
# ## Výsledky trénovania
#
# Vidíme, že najlepší model mal validačnú accuracy 0.47, ktorá bola dosiahnutá v epochu č. 47 a keďže v nasledujúcich epochoch nenastalo k jej zlepšeniu bolo použité EarlyStopping trénovania. Tento najlepší model sme  následne uložili pomocou ModelCheckpoint-u. Aj pomocou grafu vidíme, že trénovanie začalo stagnovať okolo hodnoty 0.45 - 0.47 trénovacej accuracy. Ďalšie zlepšenie modelu sa nám nepodarilo docieliť ani s viacerými nastaveniami hyperparametrov a ani upravou siete.
#
# Myslíme si, že výsledná accuracy je pomerne nízka a dôvodom bude zlá veľkosť vstupných obrázkov. ResNet50 by mal byť najefektívnejší, ak má na vstupe obrázky, ktoré majú aspoň 200x200 pixelov. Skúšali sme preto zväčšiť naše trénovacie a validačné dáta pomocou UpSampling2D, avšak na takto upravených dátach sa nám náš model nepodarilo nejako rozumne natrénovať.

# %%
fig, ax = plt.subplots(figsize=(17,8))

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy', linestyle='--')
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(17,8))

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()

# %% [markdown]
# ## Testovanie
#
# Pri vyhodnocovaní úspešnosti na testovacích dátach si najskôr načítame najlepší model z trénovania a pomocou funkcie classification_report() model vyhodnotíme. Vidíme, že model mal na testovacích dátach úspešnosť 0.47.

# %%
best_model = load_model('cifar100_best_model.h5')

# %%
y_pred = best_model.predict(x_test)
y_classes = [np.argmax(element) for element in y_pred]

print('Report: \n', classification_report(y_test, y_classes))
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85        28
#            1       0.50      0.61      0.55        31
#            2       0.41      0.40      0.41        35
#            3       0.58      0.32      0.41        44
#            4       0.23      0.28      0.25        32
#            5       0.41      0.38      0.39        37
#            6       0.53      0.47      0.50        34
#            7       0.33      0.67      0.44        18
#            8       0.47      0.71      0.56        28
#            9       0.48      0.44      0.46        25
#           10       0.50      0.31      0.38        29
#           11       0.36      0.15      0.21        33
#           12       0.60      0.44      0.51        34
#           13       0.21      0.20      0.20        30
#           14       0.35      0.57      0.43        28
#           15       0.32      0.29      0.30        28
#           16       0.55      0.68      0.61        25
#           17       0.65      0.85      0.73        26
#           18       0.59      0.71      0.65        28
#           19       0.60      0.32      0.42        37
#           20       0.50      0.66      0.57        35
#           21       0.36      0.43      0.39        23
#           22       0.59      0.68      0.63        25
